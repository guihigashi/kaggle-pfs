# %%
import glob

import ipywidgets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from kaggle_pfs.data import readers

# %%
shop_df = pd.concat(
    map(pd.read_csv, glob.glob(readers.data_path("interim", "emb-shop-*.csv"))),
    ignore_index=True,
)

# %%
_ = sns.FacetGrid(shop_df, col="epoch", col_wrap=4).map(sns.scatterplot, "x", "y")

# %%
item_df = pd.concat(
    map(pd.read_csv, glob.glob(readers.data_path("interim", "emb-item-*.csv"))),
    ignore_index=True,
)

# %%
selected_items = np.random.choice(item_df.item.unique(), size=100, replace=False)

# %%
filtered_item_df = item_df.loc[item_df.item.isin(selected_items)]

# %%
_ = sns.FacetGrid(filtered_item_df, col="epoch", col_wrap=4).map(sns.scatterplot, "x", "y")
